# %%
import utils
import pandas as pd

# %%
final_results = utils.get_error('',['STEP3-US-Prr-R-VEGC-VEGN-AM.finalresults'])
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Input In [119], in <cell line: 1>()
# ----> 1 final_results = utils.get_error('',['STEP3-US-Prr-R.finalresults'])
#
# File /work/mads_calibration/utils.py:282, in get_error(path, filenames)
#     280 file_path = os.path.join(path, filename)
#     281 #again, assumes there are three lines - 0=OF, 1=lambda, 2=params
# --> 282 with open(file_path) as f:
#     283   errors = f.readlines()
#     284 #for multiple optimal sets, need to loop through them all
#
# FileNotFoundError: [Errno 2] No such file or directory: 'STEP3-US-Prr-R.finalresults'

# %%
opt_params = utils.get_optimal_sets_of_params('STEP3-US-Prr-R-VEGC-VEGN-AM.finalresults')
y_kmeans, centers = utils.get_err_clusters(final_results)
# Out:
# /home/develop/.pyenv/versions/3.8.6/lib/python3.8/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(

# %%
centers
# Out:
# [array([5098725.23751716]),
#  array([35127612.83419305]),
#  array([2.29587854e+08]),
#  array([3.25843921e+08])]

# %%
opt_params.keys()
# Out:
# dict_keys(['cfall00', 'cfall01', 'cfall02', 'cfall03', 'cfall04', 'cfall10', 'cfall12', 'cfall20', 'cfall22', 'cfall23', 'nfall00', 'nfall01', 'nfall02', 'nfall03', 'nfall04', 'nfall10', 'nfall12', 'nfall20', 'nfall22', 'nfall23'])

# %%
keys=['nmax0', 'nmax1', 'nmax2', 'nmax3', 'nmax4']
utils.plot_stacked_histograms({key: opt_params[key] for key in keys},centers,y_kmeans)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Input In [51], in <cell line: 2>()
#       1 keys=['nmax0', 'nmax1', 'nmax2', 'nmax3', 'nmax4']
# ----> 2 utils.plot_stacked_histograms({key: opt_params[key] for key in keys},centers,y_kmeans)
#
# Input In [51], in <dictcomp>(.0)
#       1 keys=['nmax0', 'nmax1', 'nmax2', 'nmax3', 'nmax4']
# ----> 2 utils.plot_stacked_histograms({key: opt_params[key] for key in keys},centers,y_kmeans)
#
# KeyError: 'nmax0'

# %%
keys=['krb00', 'krb01', 'krb02', 'krb03', 'krb04']
utils.plot_stacked_histograms({key: opt_params[key] for key in keys},centers,y_kmeans)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Input In [52], in <cell line: 2>()
#       1 keys=['krb00', 'krb01', 'krb02', 'krb03', 'krb04']
# ----> 2 utils.plot_stacked_histograms({key: opt_params[key] for key in keys},centers,y_kmeans)
#
# Input In [52], in <dictcomp>(.0)
#       1 keys=['krb00', 'krb01', 'krb02', 'krb03', 'krb04']
# ----> 2 utils.plot_stacked_histograms({key: opt_params[key] for key in keys},centers,y_kmeans)
#
# KeyError: 'krb00'

# %%
keys=['krb10', 'krb12', 'krb20', 'krb22', 'krb23']
utils.plot_stacked_histograms({key: opt_params[key] for key in keys},centers,y_kmeans)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Input In [53], in <cell line: 2>()
#       1 keys=['krb10', 'krb12', 'krb20', 'krb22', 'krb23']
# ----> 2 utils.plot_stacked_histograms({key: opt_params[key] for key in keys},centers,y_kmeans)
#
# Input In [53], in <dictcomp>(.0)
#       1 keys=['krb10', 'krb12', 'krb20', 'krb22', 'krb23']
# ----> 2 utils.plot_stacked_histograms({key: opt_params[key] for key in keys},centers,y_kmeans)
#
# KeyError: 'krb10'

# %%
keys=['cfall00', 'cfall01', 'cfall02', 'cfall03', 'cfall04']
utils.plot_stacked_histograms({key: opt_params[key] for key in keys},centers,y_kmeans)
# Out:
# Parameter cfall03 has standard deviation(0.0) less than threshold of 0
#
# Parameter cfall04 has standard deviation(0.0) less than threshold of 0

# %%
keys=['cfall10', 'cfall12', 'cfall20', 'cfall22', 'cfall23']
utils.plot_stacked_histograms({key: opt_params[key] for key in keys},centers,y_kmeans)
# Out:
# Parameter cfall10 has standard deviation(0.0) less than threshold of 0
#
# Parameter cfall20 has standard deviation(0.0) less than threshold of 0

# %%
keys=['nfall00', 'nfall01', 'nfall02', 'nfall03', 'nfall04']
utils.plot_stacked_histograms({key: opt_params[key] for key in keys},centers,y_kmeans)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Input In [28], in <cell line: 2>()
#       1 keys=['nfall00', 'nfall01', 'nfall02', 'nfall03', 'nfall04']
# ----> 2 utils.plot_stacked_histograms({key: opt_params[key] for key in keys},centers,y_kmeans)
#
# Input In [28], in <dictcomp>(.0)
#       1 keys=['nfall00', 'nfall01', 'nfall02', 'nfall03', 'nfall04']
# ----> 2 utils.plot_stacked_histograms({key: opt_params[key] for key in keys},centers,y_kmeans)
#
# KeyError: 'nfall00'

# %%
keys=['nfall10', 'nfall12', 'nfall20', 'nfall22', 'nfall23']
utils.plot_stacked_histograms({key: opt_params[key] for key in keys},centers,y_kmeans)

# %%
target_vars = ['NPPAll1', 'NPPAll2', 'NPPAll3', 'NPPAll4', 'NPPAll5',
                   'VegCarbonLeaf1', 'VegCarbonStem1', 'VegCarbonRoot1', 'VegCarbonLeaf2', 'VegCarbonLeaf3',
                   'VegCarbonStem3', 'VegCarbonRoot3', 'VegCarbonLeaf4',
                   'VegCarbonRoot4', 'VegCarbonLeaf5',
                   'VegNitrogenLeaf1', 'VegNitrogenStem1', 'VegNitrogenRoot1', 'VegNitrogenLeaf2', 'VegNitrogenLeaf3',
                   'VegNitrogenStem3', 'VegNitrogenRoot3', 'VegNitrogenLeaf4',
                   'VegNitrogenRoot4', 'VegNitrogenLeaf5']
params = ['NPPAll1', 'NPPAll2', 'NPPAll3', 'NPPAll4', 'NPPAll5',
                   'VegCarbonLeaf1', 'VegCarbonStem1', 'VegCarbonRoot1', 'VegCarbonLeaf2', 'VegCarbonLeaf3',
                   'VegCarbonStem3', 'VegCarbonRoot3', 'VegCarbonLeaf4',
                   'VegCarbonRoot4', 'VegCarbonLeaf5',
                   'VegNitrogenLeaf1', 'VegNitrogenStem1', 'VegNitrogenRoot1', 'VegNitrogenLeaf2', 'VegNitrogenLeaf3',
                   'VegNitrogenStem3', 'VegNitrogenRoot3', 'VegNitrogenLeaf4',
                   'VegNitrogenRoot4', 'VegNitrogenLeaf5']
model_csv = utils.read_all_csv('', ['out-20230626-step3.csv'], 'model', target_vars)
#param_csv = utils.read_all_csv('', ['param-20230619-step3..csv'], 'model', params)

# %%
model_csv
# Out:
#        NPPAll1     NPPAll2     NPPAll3    NPPAll4    NPPAll5  VegCarbonLeaf1  \
# 0   255.485052  151.111926  163.181306  70.787767  15.275335      145.205594
# 1   233.139863  143.372229  145.712349  79.838254  16.885971      148.767096
# 2   247.370654  144.523726  153.902808  77.746568  17.273599      157.813568
# 3   275.779755  138.462414  167.620777  74.323463  17.031542      160.372722
# 4   258.791854  137.204372  159.134961  77.663872  16.597876      147.829028
# 5   239.337764  150.713946  151.164890  78.866125  16.997574      159.604063
# 6   227.851817  144.009050  169.833509  70.153513  17.703793      155.501602
# 7   226.938646  143.574566  146.061037  70.258862  14.567658      144.619002
# 8   232.647187  141.972515  158.591978  56.622625  15.156854      156.739891
# 9   257.068288  146.236563  154.849669  55.986344  14.442346      146.912346
# 10  153.760108   86.139895  126.960543  41.130817   8.963728      152.195740
# 11  203.142533  169.250846  162.200232  34.133985   6.792910      152.563649
# 12  172.369103   82.243158  125.621770  40.638033  18.278380      151.744034
# 13  220.888516   86.299133  180.887290  42.787025  11.539601      155.116594
# 14  229.990958   84.893832  173.035717  43.570043   8.574339      156.085693
# 15  163.409579   66.788231  117.051959  39.791734   7.357218      144.387274
# 16  129.780000   74.220000   96.696000  39.437000   7.236500      153.693200
#
#     VegCarbonStem1  VegCarbonRoot1  VegCarbonLeaf2  VegCarbonLeaf3  ...  \
# 0       557.400140     1391.624231      316.458432       10.735263  ...
# 1       508.830157     1254.840613      239.610683       10.115665  ...
# 2       563.563086     1418.821509      241.572171       10.975025  ...
# 3       652.777417     1650.976062      289.804367       11.625524  ...
# 4       572.703308     1444.544177      287.114572       12.005347  ...
# 5       544.093683     1374.934265      252.274205       11.236642  ...
# 6       558.515125     1353.314783      240.675131       10.821527  ...
# 7       510.231879     1242.503296      300.564142       10.543100  ...
# 8       568.393567     1376.187585      237.240488       12.970105  ...
# 9       567.925903     1431.143872      244.436554       11.921491  ...
# 10      411.916522      945.739221      240.619853       12.138207  ...
# 11      506.425128     1193.561084      355.301907       14.190371  ...
# 12      462.093277     1049.057153      229.653943       12.790395  ...
# 13      541.879547     1304.628125      240.227032       14.615137  ...
# 14      573.786115     1349.127747      236.298978        6.836289  ...
# 15      384.651938      901.047552      279.994525       11.889470  ...
# 16      434.136300     1120.471600      266.495000       11.360000  ...
#
#     VegNitrogenLeaf1  VegNitrogenStem1  VegNitrogenRoot1  VegNitrogenLeaf2  \
# 0           4.929555          7.490027         34.443087          3.513553
# 1           4.553421          6.837394         31.441898          2.681468
# 2          30.490591          7.572855         34.824190          2.705048
# 3          15.304686          8.772028         40.339183          3.260596
# 4           4.923523          7.695673         35.389022          3.238741
# 5          19.362515          7.311300         33.621526          2.808984
# 6          25.456044          7.505195         34.513450          2.691166
# 7           4.807827          6.856236         31.528822          3.361129
# 8          19.742304          7.637892         35.123637          2.658104
# 9           5.021342          7.631496         35.093835          2.728496
# 10          8.659125          5.552288         25.532830          3.068513
# 11         23.797087          6.805040         31.293752          3.899998
# 12         10.593222          6.209339         28.554357          2.969148
# 13         12.044229          7.359800         33.844895          3.027739
# 14          6.507926          7.710194         35.455491          2.991543
# 15          4.171142          5.168723         23.768966          3.870973
# 16          4.802900          6.730800         30.952200          3.370000
#
#     VegNitrogenLeaf3  VegNitrogenStem3  VegNitrogenRoot3  VegNitrogenLeaf4  \
# 0           0.274174          0.701677          2.661753          1.183573
# 1           0.255774          0.602569          1.828675          1.310150
# 2           0.277692          0.529651          1.931143          1.268260
# 3           0.296454          0.712635          2.165717          1.205951
# 4           0.300898          0.578577          2.109009          1.263797
# 5           0.285409          0.627207          1.906351          1.216165
# 6           0.274168          0.712047          2.165055          1.183019
# 7           0.265046          0.619718          2.355014          1.196826
# 8           0.331221          0.577456          1.753578          1.273850
# 9           0.306430          0.676621          2.571429          1.228316
# 10          0.296303          0.666574          2.031141          1.250636
# 11          0.360301          1.220370          3.719466          1.625987
# 12          0.318334          0.964448          2.203070          1.108930
# 13          0.392490          1.374232          2.503609          1.281521
# 14          0.182251          0.578912          2.120223          1.462753
# 15          0.323423          0.612476          1.864413          1.753648
# 16          0.284000          0.556000          1.694000          0.964700
#
#     VegNitrogenRoot4  VegNitrogenLeaf5
# 0           1.249127          0.198556
# 1           1.665658          0.217808
# 2           1.632640          0.222424
# 3           1.567817          0.219174
# 4           1.628123          0.214159
# 5           1.646344          0.219371
# 6           1.879607          0.286395
# 7           1.877143          0.240431
# 8           1.611233          0.249229
# 9           1.591431          0.323644
# 10          1.706618          0.131591
# 11          1.597847          0.181938
# 12          1.695515          0.235408
# 13          1.773879          0.130259
# 14          1.793947          0.211037
# 15          1.657976          0.294141
# 16          1.630000          0.251100
#
# [17 rows x 25 columns]

# %%
def spaghetti_match_plot(df_x,df_y,logy=True):
    ''' plots the spaghetti plot of modeled v.s. observed values 
        df_x: parameter dataframe
        df_y: model output dataframe
        logy: True enables the logplot option
    '''
    ax = df_y.transpose().plot(logy=logy,legend=False,alpha=0.5,figsize=(10,5))
    
    nrange=range(len(df_y.columns))
    df_x.plot(logy=logy,legend=True,style="o",color='red',xticks=nrange, rot=90, label="Targets", ax=ax);
    df_x.plot(logy=logy,legend=False,style="o",color='red',xticks=nrange, rot=90,ax=ax)
    ax.set_xticklabels(df_y.columns,fontsize=12)

# %%
pd.DataFrame(model_csv.iloc[-1])
# Out:
#                          16
# NPPAll1            129.7800
# NPPAll2             74.2200
# NPPAll3             96.6960
# NPPAll4             39.4370
# NPPAll5              7.2365
# VegCarbonLeaf1     153.6932
# VegCarbonStem1     434.1363
# VegCarbonRoot1    1120.4716
# VegCarbonLeaf2     266.4950
# VegCarbonLeaf3      11.3600
# VegCarbonStem3      59.6400
# VegCarbonRoot3      86.5000
# VegCarbonLeaf4      32.8000
# VegCarbonRoot4     117.1428
# VegCarbonLeaf5      28.3776
# VegNitrogenLeaf1     4.8029
# VegNitrogenStem1     6.7308
# VegNitrogenRoot1    30.9522
# VegNitrogenLeaf2     3.3700
# VegNitrogenLeaf3     0.2840
# VegNitrogenStem3     0.5560
# VegNitrogenRoot3     1.6940
# VegNitrogenLeaf4     0.9647
# VegNitrogenRoot4     1.6300
# VegNitrogenLeaf5     0.2511

# %%
pd.DataFrame(model_csv.iloc[2])
# Out:
#                             2
# NPPAll1            247.370654
# NPPAll2            144.523726
# NPPAll3            153.902808
# NPPAll4             77.746568
# NPPAll5             17.273599
# VegCarbonLeaf1     157.813568
# VegCarbonStem1     563.563086
# VegCarbonRoot1    1418.821509
# VegCarbonLeaf2     241.572171
# VegCarbonLeaf3      10.975025
# VegCarbonStem3      65.392707
# VegCarbonRoot3     103.881165
# VegCarbonLeaf4      42.434829
# VegCarbonRoot4     129.780304
# VegCarbonLeaf5      28.853664
# VegNitrogenLeaf1    30.490591
# VegNitrogenStem1     7.572855
# VegNitrogenRoot1    34.824190
# VegNitrogenLeaf2     2.705048
# VegNitrogenLeaf3     0.277692
# VegNitrogenStem3     0.529651
# VegNitrogenRoot3     1.931143
# VegNitrogenLeaf4     1.268260
# VegNitrogenRoot4     1.632640
# VegNitrogenLeaf5     0.222424

# %%
model_csv
# Out:
#        NPPAll1     NPPAll2     NPPAll3    NPPAll4    NPPAll5  VegCarbonLeaf1  \
# 0   255.485052  151.111926  163.181306  70.787767  15.275335      145.205594
# 1   233.139863  143.372229  145.712349  79.838254  16.885971      148.767096
# 2   247.370654  144.523726  153.902808  77.746568  17.273599      157.813568
# 3   275.779755  138.462414  167.620777  74.323463  17.031542      160.372722
# 4   258.791854  137.204372  159.134961  77.663872  16.597876      147.829028
# 5   239.337764  150.713946  151.164890  78.866125  16.997574      159.604063
# 6   227.851817  144.009050  169.833509  70.153513  17.703793      155.501602
# 7   226.938646  143.574566  146.061037  70.258862  14.567658      144.619002
# 8   232.647187  141.972515  158.591978  56.622625  15.156854      156.739891
# 9   257.068288  146.236563  154.849669  55.986344  14.442346      146.912346
# 10  153.760108   86.139895  126.960543  41.130817   8.963728      152.195740
# 11  203.142533  169.250846  162.200232  34.133985   6.792910      152.563649
# 12  172.369103   82.243158  125.621770  40.638033  18.278380      151.744034
# 13  220.888516   86.299133  180.887290  42.787025  11.539601      155.116594
# 14  229.990958   84.893832  173.035717  43.570043   8.574339      156.085693
# 15  163.409579   66.788231  117.051959  39.791734   7.357218      144.387274
# 16  129.780000   74.220000   96.696000  39.437000   7.236500      153.693200
#
#     VegCarbonStem1  VegCarbonRoot1  VegCarbonLeaf2  VegCarbonLeaf3  ...  \
# 0       557.400140     1391.624231      316.458432       10.735263  ...
# 1       508.830157     1254.840613      239.610683       10.115665  ...
# 2       563.563086     1418.821509      241.572171       10.975025  ...
# 3       652.777417     1650.976062      289.804367       11.625524  ...
# 4       572.703308     1444.544177      287.114572       12.005347  ...
# 5       544.093683     1374.934265      252.274205       11.236642  ...
# 6       558.515125     1353.314783      240.675131       10.821527  ...
# 7       510.231879     1242.503296      300.564142       10.543100  ...
# 8       568.393567     1376.187585      237.240488       12.970105  ...
# 9       567.925903     1431.143872      244.436554       11.921491  ...
# 10      411.916522      945.739221      240.619853       12.138207  ...
# 11      506.425128     1193.561084      355.301907       14.190371  ...
# 12      462.093277     1049.057153      229.653943       12.790395  ...
# 13      541.879547     1304.628125      240.227032       14.615137  ...
# 14      573.786115     1349.127747      236.298978        6.836289  ...
# 15      384.651938      901.047552      279.994525       11.889470  ...
# 16      434.136300     1120.471600      266.495000       11.360000  ...
#
#     VegNitrogenLeaf1  VegNitrogenStem1  VegNitrogenRoot1  VegNitrogenLeaf2  \
# 0           4.929555          7.490027         34.443087          3.513553
# 1           4.553421          6.837394         31.441898          2.681468
# 2          30.490591          7.572855         34.824190          2.705048
# 3          15.304686          8.772028         40.339183          3.260596
# 4           4.923523          7.695673         35.389022          3.238741
# 5          19.362515          7.311300         33.621526          2.808984
# 6          25.456044          7.505195         34.513450          2.691166
# 7           4.807827          6.856236         31.528822          3.361129
# 8          19.742304          7.637892         35.123637          2.658104
# 9           5.021342          7.631496         35.093835          2.728496
# 10          8.659125          5.552288         25.532830          3.068513
# 11         23.797087          6.805040         31.293752          3.899998
# 12         10.593222          6.209339         28.554357          2.969148
# 13         12.044229          7.359800         33.844895          3.027739
# 14          6.507926          7.710194         35.455491          2.991543
# 15          4.171142          5.168723         23.768966          3.870973
# 16          4.802900          6.730800         30.952200          3.370000
#
#     VegNitrogenLeaf3  VegNitrogenStem3  VegNitrogenRoot3  VegNitrogenLeaf4  \
# 0           0.274174          0.701677          2.661753          1.183573
# 1           0.255774          0.602569          1.828675          1.310150
# 2           0.277692          0.529651          1.931143          1.268260
# 3           0.296454          0.712635          2.165717          1.205951
# 4           0.300898          0.578577          2.109009          1.263797
# 5           0.285409          0.627207          1.906351          1.216165
# 6           0.274168          0.712047          2.165055          1.183019
# 7           0.265046          0.619718          2.355014          1.196826
# 8           0.331221          0.577456          1.753578          1.273850
# 9           0.306430          0.676621          2.571429          1.228316
# 10          0.296303          0.666574          2.031141          1.250636
# 11          0.360301          1.220370          3.719466          1.625987
# 12          0.318334          0.964448          2.203070          1.108930
# 13          0.392490          1.374232          2.503609          1.281521
# 14          0.182251          0.578912          2.120223          1.462753
# 15          0.323423          0.612476          1.864413          1.753648
# 16          0.284000          0.556000          1.694000          0.964700
#
#     VegNitrogenRoot4  VegNitrogenLeaf5
# 0           1.249127          0.198556
# 1           1.665658          0.217808
# 2           1.632640          0.222424
# 3           1.567817          0.219174
# 4           1.628123          0.214159
# 5           1.646344          0.219371
# 6           1.879607          0.286395
# 7           1.877143          0.240431
# 8           1.611233          0.249229
# 9           1.591431          0.323644
# 10          1.706618          0.131591
# 11          1.597847          0.181938
# 12          1.695515          0.235408
# 13          1.773879          0.130259
# 14          1.793947          0.211037
# 15          1.657976          0.294141
# 16          1.630000          0.251100
#
# [17 rows x 25 columns]

# %%
spaghetti_match_plot(pd.DataFrame(model_csv.iloc[-1]), model_csv[-2:-1])

# %%
param_csv
# Out:
#    VegCarbonLeaf1  VegCarbonStem1  VegCarbonRoot1  VegCarbonLeaf2  \
# 0            0.01            0.05            0.23             0.0
# 1            0.00            0.05            0.22             0.0
# 2            0.01            0.05            0.17             0.0
# 3            0.01            0.04            0.15             0.0
# 4            0.01            0.05            0.20             0.0
# 5            0.00            0.05            0.21             0.0
# 6            0.00            0.05            0.19             0.0
#
#    VegCarbonLeaf3  VegCarbonStem3  VegCarbonRoot3  VegCarbonLeaf4  \
# 0            0.05            0.01            0.04            0.01
# 1            0.05            0.01            0.07            0.01
# 2            0.05            0.01            0.07            0.01
# 3            0.05            0.01            0.05            0.01
# 4            0.05            0.01            0.07            0.01
# 5            0.05            0.01            0.05            0.01
# 6            0.05            0.01            0.04            0.01
#
#    VegCarbonRoot4  VegCarbonLeaf5  VegNitrogenLeaf1  VegNitrogenStem1  \
# 0            0.06            0.05              0.15              0.00
# 1            0.07            0.05              0.00              0.01
# 2            0.07            0.05              0.00              0.07
# 3            0.05            0.03              0.00              0.00
# 4            0.07            0.04              0.18              0.10
# 5            0.05            0.05              0.00              0.00
# 6            0.05            0.05              0.00              0.00
#
#    VegNitrogenRoot1  VegNitrogenLeaf2  VegNitrogenLeaf3  VegNitrogenStem3  \
# 0              0.00              0.07              0.00              0.00
# 1              0.01              0.00              0.07              0.00
# 2              0.00              0.00              0.00              0.03
# 3              0.00              0.00              0.08              0.00
# 4              0.00              0.00              0.05              0.00
# 5              0.00              0.00              0.00              0.07
# 6              0.00              0.00              0.00              0.05
#
#    VegNitrogenRoot3  VegNitrogenLeaf4  VegNitrogenRoot4  VegNitrogenLeaf5
# 0               0.0              0.10              0.10              0.00
# 1               0.0              0.06              0.00              0.00
# 2               0.0              0.07              0.00              0.00
# 3               0.1              0.05              0.00              0.09
# 4               0.0              0.03              0.00              0.00
# 5               0.0              0.01              0.10              0.01
# 6               0.0              0.01              0.08              0.00
