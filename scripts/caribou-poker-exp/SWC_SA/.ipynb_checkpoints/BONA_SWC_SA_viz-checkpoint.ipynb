# %%
import sys
# caution: path[0] is reserved for script path (or '' in REPL)
sys.path.insert(1, '/work/scripts/util')
from output import load_trsc_dataframe
import os
import output as ou
import pandas as pd
import xarray as xr
import numpy as np
import seaborn as sns
from matplotlib import pyplot as plt
from sklearn.metrics import r2_score

# %%
SA_path = '/data/workflows/BONA_black_spruce_SWC_SA/'
#SA_path = '/data/workflows/BONA_birch_SWC_SA/'
run_dirs=[os.path.join(SA_path, f) for f in os.listdir(SA_path) if ('sample' in f) and not ('.' in f)]

varlist = ['LAYERDEPTH', 'LAYERDZ', 'LAYERTYPE', 'TLAYER', 'LWCLAYER']
cell_x_coord = 0
cell_y_coord = 0

# WTT2, WTT3, DF2 - birch

# WTT1 - black spruce

# %%
depthlist = [0.15,0.4]

def get_lwclayer_tlayer(depthlist, run_dir, var):
    
    ### read the netcdf output files and compute year from the time dimension
    data = xr.open_dataset(f'{run_dir}/output/{var}_monthly_tr.nc')
    data = data.to_dataframe()
    data.reset_index(inplace=True)
    data.dtypes
    data['time'] = data['time'].astype('|S80')
    data['time'] = data['time'].astype('|datetime64[ns]')
    data['month'] = data['time'].dt.month
    data['year'] = data['time'].dt.year
    data = data.sort_values(['time','x','y','layer'])


    ### read the netcdf output files on soil structure and compute year from the time dimension
    dz = xr.open_dataset(f'{run_dir}/output/LAYERDZ_monthly_tr.nc')
    dz = dz.to_dataframe()
    dz.reset_index(inplace=True)
    dz.dtypes
    dz['time'] = dz['time'].astype('|S80')
    dz['time'] = dz['time'].astype('|datetime64[ns]')
    dz['month'] = dz['time'].dt.month
    dz['year'] = dz['time'].dt.year
    dz = dz.sort_values(['time','x','y','layer'])

    ### read the netcdf output files on soil structure and compute year from the time dimension
    lt = xr.open_dataset(f'{run_dir}/output/LAYERTYPE_monthly_tr.nc')
    lt = lt.to_dataframe()
    lt.reset_index(inplace=True)
    lt.dtypes
    lt['time'] = lt['time'].astype('|S80')
    lt['time'] = lt['time'].astype('|datetime64[ns]')
    lt['month'] = lt['time'].dt.month
    lt['year'] = lt['time'].dt.year
    lt = lt.sort_values(['time','x','y','layer'])
    dz=pd.merge(dz, lt[['LAYERTYPE', 'time', 'x', 'y', 'layer']], on=['time','x','y','layer'])


    ### compute the depth of the bottom of every layers
    dz['z'] = dz.groupby(['time','x','y'])['LAYERDZ'].cumsum(axis=0)
    
    ### loop through the list of depths of reference to compute the soil variable at that depth via linear interpolation
    stdz = []
    for i in range(len(depthlist)):
        dpth = depthlist[i]
        print("depth:", dpth,"m")
        # extract the top and bottom layers the closest to the depth of reference
        dz['diff'] = dz['z']-float(dpth)
        top = dz.loc[dz[(dz['diff'] <= 0)].groupby(['time','x','y'])['diff'].idxmax()]
        bot = dz.loc[dz[(dz['diff'] >= 0)].groupby(['time','x','y'])['diff'].idxmin()]
        # select the variable value for each of these top and bottom layers
        datatop = pd.merge(data, top[['year','month', 'x','y','layer','LAYERDZ','LAYERTYPE','z']], how="left", on=['layer','year','month', 'x','y'])
        datatop = datatop[datatop['z'].notna()]
        datatop = datatop.rename(columns={"layer": "layertop", var: var+"top", "LAYERDZ": "dztop", "z": "ztop", "LAYERTYPE": "typetop"})
        databot = pd.merge(data, bot[['year', 'month', 'x','y','layer','LAYERDZ','LAYERTYPE','z']], how="left", on=['layer','year','month' , 'x','y'])
        databot = databot[databot['z'].notna()]
        databot = databot.rename(columns={"layer": "layerbot", var: var+"bot", "LAYERDZ": "dzbot", "z": "zbot", "LAYERTYPE": "typebot"})
        # merge the data to do the linear interpolation
        datastdz = pd.merge(datatop, databot, how="outer", on=['time','year', 'month', 'x','y'])
        datastdz['a'] = (datastdz[var+"top"] - datastdz[var+"bot"]) / (datastdz['ztop'] - datastdz['zbot'])
        datastdz['b'] = datastdz[var+"top"] - (datastdz['a'] * datastdz['ztop'])
        datastdz[var] = (datastdz['a'] * float(dpth)) + datastdz['b']
        datastdz[var+'_top'] = datastdz[var+"top"]
        datastdz[var+'_bot'] = datastdz[var+"bot"]
        datastdz['z'] = float(dpth)
        datastdz['layer'] = i
        datastdz['type'] = datastdz['typebot']
        datastdz = datastdz[['time','x','y','layer','z','type',var, var+'_top', var+'_bot']]
        stdz.append(datastdz)

    stdz = pd.concat(stdz)
    
    return stdz

# %%
lwc_layers = []
t_layers = []
sample_dfs=[]
for d in run_dirs:
    if 'GPP_monthly_tr.nc' in os.listdir(os.path.join(d, 'output')):
        sample = int(d.split('/')[-1].split('_')[-1])
        TLAYER = ou.load_trsc_dataframe(var ='TLAYER', timeres='monthly', px_y=cell_y_coord, px_x=cell_x_coord, fileprefix=f'{d}/output/')[0]
        LAYERDEPTH = ou.load_trsc_dataframe(var ='LAYERDEPTH', timeres='monthly', px_y=cell_y_coord, px_x=cell_x_coord, fileprefix=f'{d}/output/')[0]
        LAYERDZ = ou.load_trsc_dataframe(var ='LAYERDZ', timeres='monthly', px_y=cell_y_coord, px_x=cell_x_coord, fileprefix=f'{d}/output/')[0]
        GPP = ou.load_trsc_dataframe(var ='GPP', timeres='monthly', px_y=cell_y_coord, px_x=cell_x_coord, fileprefix=f'{d}/output/')[0][0]
        ALD = ou.load_trsc_dataframe(var ='ALD', timeres='yearly', px_y=cell_y_coord, px_x=cell_x_coord, fileprefix=f'{d}/output/')[0][0]
        RH = ou.load_trsc_dataframe(var ='RH', timeres='monthly', px_y=cell_y_coord, px_x=cell_x_coord, fileprefix=f'{d}/output/')[0][0]
        ALD.columns=['ALD']
        sample_df = pd.DataFrame({'date': GPP.index, 'sample': [sample]*len(GPP), #'LWCLAYER': LWCLAYER, 'TLAYER': TLAYER, 'LAYERDEPTH': LAYERDEPTH, 'LAYERDZ': LAYERDZ,
                                  'GPP': GPP, 'RH':RH})
        sample_df = pd.merge(sample_df, ALD, how='left', left_on='date', right_index=True)
        sample_dfs.append(sample_df)
        
        LWCLAYER = get_lwclayer_tlayer(depthlist, d, 'LWCLAYER')
        LWCLAYER['sample'] = sample
        lwc_layers.append(LWCLAYER)
        
        TLAYER = get_lwclayer_tlayer(depthlist, d, 'TLAYER')
        TLAYER['sample'] = sample
        t_layers.append(TLAYER)
        
sample_dfs=pd.concat(sample_dfs)
lwc_layers=pd.concat(lwc_layers)
t_layers=pd.concat(t_layers)
# Out:
# Trying to open:  /data/workflows/BONA_black_spruce_SWC_SA/sample_000000038/output/TLAYER_monthly_tr.nc
# Trying to open:  /data/workflows/BONA_black_spruce_SWC_SA/sample_000000038/output/LAYERDEPTH_monthly_tr.nc
# Trying to open:  /data/workflows/BONA_black_spruce_SWC_SA/sample_000000038/output/LAYERDZ_monthly_tr.nc
# Trying to open:  /data/workflows/BONA_black_spruce_SWC_SA/sample_000000038/output/GPP_monthly_tr.nc
# Trying to open:  /data/workflows/BONA_black_spruce_SWC_SA/sample_000000038/output/ALD_yearly_tr.nc
# Trying to open:  /data/workflows/BONA_black_spruce_SWC_SA/sample_000000038/output/RH_monthly_tr.nc
# depth: 0.15 m
# depth: 0.4 m
# depth: 0.15 m
# depth: 0.4 m
# Trying to open:  /data/workflows/BONA_black_spruce_SWC_SA/sample_000000040/output/TLAYER_monthly_tr.nc
# Trying to open:  /data/workflows/BONA_black_spruce_SWC_SA/sample_000000040/output/LAYERDEPTH_monthly_tr.nc
# Trying to open:  /data/workflows/BONA_black_spruce_SWC_SA/sample_000000040/output/LAYERDZ_monthly_tr.nc
# Trying to open:  /data/workflows/BONA_black_spruce_SWC_SA/sample_000000040/output/GPP_monthly_tr.nc
# Trying to open:  /data/workflows/BONA_black_spruce_SWC_SA/sample_000000040/output/ALD_yearly_tr.nc
# Trying to open:  /data/workflows/BONA_black_spruce_SWC_SA/sample_000000040/output/RH_monthly_tr.nc
# depth: 0.15 m
# depth: 0.4 m
# depth: 0.15 m
# depth: 0.4 m
# Trying to open:  /data/workflows/BONA_black_spruce_SWC_SA/sample_000000015/output/TLAYER_monthly_tr.nc
# Trying to open:  /data/workflows/BONA_black_spruce_SWC_SA/sample_000000015/output/LAYERDEPTH_monthly_tr.nc
# Trying to open:  /data/workflows/BONA_black_spruce_SWC_SA/sample_000000015/output/LAYERDZ_monthly_tr.nc
# Trying to open:  /data/workflows/BONA_black_spruce_SWC_SA/sample_000000015/output/GPP_monthly_tr.nc
# Trying to open:  /data/workflows/BONA_black_spruce_SWC_SA/sample_000000015/output/ALD_yearly_tr.nc
# Trying to open:  /data/workflows/BONA_black_spruce_SWC_SA/sample_000000015/output/RH_monthly_tr.nc
# depth: 0.15 m
# depth: 0.4 m
# depth: 0.15 m
# depth: 0.4 m
# Trying to open:  /data/workflows/BONA_black_spruce_SWC_SA/sample_000000003/output/TLAYER_monthly_tr.nc
# Trying to open:  /data/workflows/BONA_black_spruce_SWC_SA/sample_000000003/output/LAYERDEPTH_monthly_tr.nc
# Trying to open:  /data/workflows/BONA_black_spruce_SWC_SA/sample_000000003/output/LAYERDZ_monthly_tr.nc
# Trying to open:  /data/workflows/BONA_black_spruce_SWC_SA/sample_000000003/output/GPP_monthly_tr.nc
# Trying to open:  /data/workflows/BONA_black_spruce_SWC_SA/sample_000000003/output/ALD_yearly_tr.nc
# Trying to open:  /data/workflows/BONA_black_spruce_SWC_SA/sample_000000003/output/RH_monthly_tr.nc
# depth: 0.15 m
# depth: 0.4 m
# depth: 0.15 m
# depth: 0.4 m
# Trying to open:  /data/workflows/BONA_black_spruce_SWC_SA/sample_000000004/output/TLAYER_monthly_tr.nc
# Trying to open:  /data/workflows/BONA_black_spruce_SWC_SA/sample_000000004/output/LAYERDEPTH_monthly_tr.nc
# Trying to open:  /data/workflows/BONA_black_spruce_SWC_SA/sample_000000004/output/LAYERDZ_monthly_tr.nc
# Trying to open:  /data/workflows/BONA_black_spruce_SWC_SA/sample_000000004/output/GPP_monthly_tr.nc
# Trying to open:  /data/workflows/BONA_black_spruce_SWC_SA/sample_000000004/output/ALD_yearly_tr.nc
# Trying to open:  /data/workflows/BONA_black_spruce_SWC_SA/sample_000000004/output/RH_monthly_tr.nc
# depth: 0.15 m
# depth: 0.4 m
# depth: 0.15 m
# depth: 0.4 m
# Trying to open:  /data/workflows/BONA_black_spruce_SWC_SA/sample_000000048/output/TLAYER_monthly_tr.nc
# Trying to open:  /data/workflows/BONA_black_spruce_SWC_SA/sample_000000048/output/LAYERDEPTH_monthly_tr.nc
# Trying to open:  /data/workflows/BONA_black_spruce_SWC_SA/sample_000000048/output/LAYERDZ_monthly_tr.nc
# Trying to open:  /data/workflows/BONA_black_spruce_SWC_SA/sample_000000048/output/GPP_monthly_tr.nc
# Trying to open:  /data/workflows/BONA_black_spruce_SWC_SA/sample_000000048/output/ALD_yearly_tr.nc
# Trying to open:  /data/workflows/BONA_black_spruce_SWC_SA/sample_000000048/output/RH_monthly_tr.nc
# depth: 0.15 m
# depth: 0.4 m
# depth: 0.15 m
# depth: 0.4 m
# Trying to open:  /data/workflows/BONA_black_spruce_SWC_SA/sample_000000041/output/TLAYER_monthly_tr.nc
# Trying to open:  /data/workflows/BONA_black_spruce_SWC_SA/sample_000000041/output/LAYERDEPTH_monthly_tr.nc
# Trying to open:  /data/workflows/BONA_black_spruce_SWC_SA/sample_000000041/output/LAYERDZ_monthly_tr.nc
# Trying to open:  /data/workflows/BONA_black_spruce_SWC_SA/sample_000000041/output/GPP_monthly_tr.nc
# Trying to open:  /data/workflows/BONA_black_spruce_SWC_SA/sample_000000041/output/ALD_yearly_tr.nc
# Trying to open:  /data/workflows/BONA_black_spruce_SWC_SA/sample_000000041/output/RH_monthly_tr.nc
# depth: 0.15 m
# depth: 0.4 m
# depth: 0.15 m
# depth: 0.4 m
# Trying to open:  /data/workflows/BONA_black_spruce_SWC_SA/sample_000000019/output/TLAYER_monthly_tr.nc
# Trying to open:  /data/workflows/BONA_black_spruce_SWC_SA/sample_000000019/output/LAYERDEPTH_monthly_tr.nc
# Trying to open:  /data/workflows/BONA_black_spruce_SWC_SA/sample_000000019/output/LAYERDZ_monthly_tr.nc
# Trying to open:  /data/workflows/BONA_black_spruce_SWC_SA/sample_000000019/output/GPP_monthly_tr.nc
# Trying to open:  /data/workflows/BONA_black_spruce_SWC_SA/sample_000000019/output/ALD_yearly_tr.nc
# Trying to open:  /data/workflows/BONA_black_spruce_SWC_SA/sample_000000019/output/RH_monthly_tr.nc
# depth: 0.15 m
# depth: 0.4 m
# depth: 0.15 m
# depth: 0.4 m
# Trying to open:  /data/workflows/BONA_black_spruce_SWC_SA/sample_000000011/output/TLAYER_monthly_tr.nc
# Trying to open:  /data/workflows/BONA_black_spruce_SWC_SA/sample_000000011/output/LAYERDEPTH_monthly_tr.nc
# Trying to open:  /data/workflows/BONA_black_spruce_SWC_SA/sample_000000011/output/LAYERDZ_monthly_tr.nc
# Trying to open:  /data/workflows/BONA_black_spruce_SWC_SA/sample_000000011/output/GPP_monthly_tr.nc
# Trying to open:  /data/workflows/BONA_black_spruce_SWC_SA/sample_000000011/output/ALD_yearly_tr.nc
# Trying to open:  /data/workflows/BONA_black_spruce_SWC_SA/sample_000000011/output/RH_monthly_tr.nc
# depth: 0.15 m
# depth: 0.4 m
# depth: 0.15 m
# depth: 0.4 m
# Trying to open:  /data/workflows/BONA_black_spruce_SWC_SA/sample_000000039/output/TLAYER_monthly_tr.nc
# Trying to open:  /data/workflows/BONA_black_spruce_SWC_SA/sample_000000039/output/LAYERDEPTH_monthly_tr.nc
# Trying to open:  /data/workflows/BONA_black_spruce_SWC_SA/sample_000000039/output/LAYERDZ_monthly_tr.nc
# Trying to open:  /data/workflows/BONA_black_spruce_SWC_SA/sample_000000039/output/GPP_monthly_tr.nc
# Trying to open:  /data/workflows/BONA_black_spruce_SWC_SA/sample_000000039/output/ALD_yearly_tr.nc
# Trying to open:  /data/workflows/BONA_black_spruce_SWC_SA/sample_000000039/output/RH_monthly_tr.nc
# depth: 0.15 m
# depth: 0.4 m
# depth: 0.15 m
# depth: 0.4 m
# Trying to open:  /data/workflows/BONA_black_spruce_SWC_SA/sample_000000032/output/TLAYER_monthly_tr.nc
# Trying to open:  /data/workflows/BONA_black_spruce_SWC_SA/sample_000000032/output/LAYERDEPTH_monthly_tr.nc
# Trying to open:  /data/workflows/BONA_black_spruce_SWC_SA/sample_000000032/output/LAYERDZ_monthly_tr.nc
# Trying to open:  /data/workflows/BONA_black_spruce_SWC_SA/sample_000000032/output/GPP_monthly_tr.nc
# Trying to open:  /data/workflows/BONA_black_spruce_SWC_SA/sample_000000032/output/ALD_yearly_tr.nc
# Trying to open:  /data/workflows/BONA_black_spruce_SWC_SA/sample_000000032/output/RH_monthly_tr.nc
# depth: 0.15 m
# depth: 0.4 m
# depth: 0.15 m
# depth: 0.4 m
# Trying to open:  /data/workflows/BONA_black_spruce_SWC_SA/sample_000000034/output/TLAYER_monthly_tr.nc
# Trying to open:  /data/workflows/BONA_black_spruce_SWC_SA/sample_000000034/output/LAYERDEPTH_monthly_tr.nc
# Trying to open:  /data/workflows/BONA_black_spruce_SWC_SA/sample_000000034/output/LAYERDZ_monthly_tr.nc
# Trying to open:  /data/workflows/BONA_black_spruce_SWC_SA/sample_000000034/output/GPP_monthly_tr.nc
# Trying to open:  /data/workflows/BONA_black_spruce_SWC_SA/sample_000000034/output/ALD_yearly_tr.nc
# Trying to open:  /data/workflows/BONA_black_spruce_SWC_SA/sample_000000034/output/RH_monthly_tr.nc
# depth: 0.15 m
# depth: 0.4 m
# depth: 0.15 m
# depth: 0.4 m
# Trying to open:  /data/workflows/BONA_black_spruce_SWC_SA/sample_000000042/output/TLAYER_monthly_tr.nc
# Trying to open:  /data/workflows/BONA_black_spruce_SWC_SA/sample_000000042/output/LAYERDEPTH_monthly_tr.nc
# Trying to open:  /data/workflows/BONA_black_spruce_SWC_SA/sample_000000042/output/LAYERDZ_monthly_tr.nc
# Trying to open:  /data/workflows/BONA_black_spruce_SWC_SA/sample_000000042/output/GPP_monthly_tr.nc
# Trying to open:  /data/workflows/BONA_black_spruce_SWC_SA/sample_000000042/output/ALD_yearly_tr.nc
# Trying to open:  /data/workflows/BONA_black_spruce_SWC_SA/sample_000000042/output/RH_monthly_tr.nc
# depth: 0.15 m
# depth: 0.4 m
# depth: 0.15 m
# depth: 0.4 m
# Trying to open:  /data/workflows/BONA_black_spruce_SWC_SA/sample_000000035/output/TLAYER_monthly_tr.nc
# Trying to open:  /data/workflows/BONA_black_spruce_SWC_SA/sample_000000035/output/LAYERDEPTH_monthly_tr.nc
# Trying to open:  /data/workflows/BONA_black_spruce_SWC_SA/sample_000000035/output/LAYERDZ_monthly_tr.nc
# Trying to open:  /data/workflows/BONA_black_spruce_SWC_SA/sample_000000035/output/GPP_monthly_tr.nc
# Trying to open:  /data/workflows/BONA_black_spruce_SWC_SA/sample_000000035/output/ALD_yearly_tr.nc
# Trying to open:  /data/workflows/BONA_black_spruce_SWC_SA/sample_000000035/output/RH_monthly_tr.nc
# depth: 0.15 m
# depth: 0.4 m
# depth: 0.15 m
# depth: 0.4 m
# Trying to open:  /data/workflows/BONA_black_spruce_SWC_SA/sample_000000001/output/TLAYER_monthly_tr.nc
# Trying to open:  /data/workflows/BONA_black_spruce_SWC_SA/sample_000000001/output/LAYERDEPTH_monthly_tr.nc
# Trying to open:  /data/workflows/BONA_black_spruce_SWC_SA/sample_000000001/output/LAYERDZ_monthly_tr.nc
# Trying to open:  /data/workflows/BONA_black_spruce_SWC_SA/sample_000000001/output/GPP_monthly_tr.nc
# Trying to open:  /data/workflows/BONA_black_spruce_SWC_SA/sample_000000001/output/ALD_yearly_tr.nc
# Trying to open:  /data/workflows/BONA_black_spruce_SWC_SA/sample_000000001/output/RH_monthly_tr.nc
# depth: 0.15 m
# depth: 0.4 m
# depth: 0.15 m
# depth: 0.4 m
# Trying to open:  /data/workflows/BONA_black_spruce_SWC_SA/sample_000000022/output/TLAYER_monthly_tr.nc
# Trying to open:  /data/workflows/BONA_black_spruce_SWC_SA/sample_000000022/output/LAYERDEPTH_monthly_tr.nc
# Trying to open:  /data/workflows/BONA_black_spruce_SWC_SA/sample_000000022/output/LAYERDZ_monthly_tr.nc
# Trying to open:  /data/workflows/BONA_black_spruce_SWC_SA/sample_000000022/output/GPP_monthly_tr.nc
# Trying to open:  /data/workflows/BONA_black_spruce_SWC_SA/sample_000000022/output/ALD_yearly_tr.nc
# Trying to open:  /data/workflows/BONA_black_spruce_SWC_SA/sample_000000022/output/RH_monthly_tr.nc
# depth: 0.15 m
# depth: 0.4 m
# depth: 0.15 m
# depth: 0.4 m
# Trying to open:  /data/workflows/BONA_black_spruce_SWC_SA/sample_000000026/output/TLAYER_monthly_tr.nc
# Trying to open:  /data/workflows/BONA_black_spruce_SWC_SA/sample_000000026/output/LAYERDEPTH_monthly_tr.nc
# Trying to open:  /data/workflows/BONA_black_spruce_SWC_SA/sample_000000026/output/LAYERDZ_monthly_tr.nc
# Trying to open:  /data/workflows/BONA_black_spruce_SWC_SA/sample_000000026/output/GPP_monthly_tr.nc
# Trying to open:  /data/workflows/BONA_black_spruce_SWC_SA/sample_000000026/output/ALD_yearly_tr.nc
# Trying to open:  /data/workflows/BONA_black_spruce_SWC_SA/sample_000000026/output/RH_monthly_tr.nc
# depth: 0.15 m
# depth: 0.4 m
# depth: 0.15 m
# depth: 0.4 m
# Trying to open:  /data/workflows/BONA_black_spruce_SWC_SA/sample_000000049/output/TLAYER_monthly_tr.nc
# Trying to open:  /data/workflows/BONA_black_spruce_SWC_SA/sample_000000049/output/LAYERDEPTH_monthly_tr.nc
# Trying to open:  /data/workflows/BONA_black_spruce_SWC_SA/sample_000000049/output/LAYERDZ_monthly_tr.nc
# Trying to open:  /data/workflows/BONA_black_spruce_SWC_SA/sample_000000049/output/GPP_monthly_tr.nc
# Trying to open:  /data/workflows/BONA_black_spruce_SWC_SA/sample_000000049/output/ALD_yearly_tr.nc
# Trying to open:  /data/workflows/BONA_black_spruce_SWC_SA/sample_000000049/output/RH_monthly_tr.nc
# depth: 0.15 m
# depth: 0.4 m
# depth: 0.15 m
# depth: 0.4 m
# Trying to open:  /data/workflows/BONA_black_spruce_SWC_SA/sample_000000021/output/TLAYER_monthly_tr.nc
# Trying to open:  /data/workflows/BONA_black_spruce_SWC_SA/sample_000000021/output/LAYERDEPTH_monthly_tr.nc
# Trying to open:  /data/workflows/BONA_black_spruce_SWC_SA/sample_000000021/output/LAYERDZ_monthly_tr.nc
# Trying to open:  /data/workflows/BONA_black_spruce_SWC_SA/sample_000000021/output/GPP_monthly_tr.nc
# Trying to open:  /data/workflows/BONA_black_spruce_SWC_SA/sample_000000021/output/ALD_yearly_tr.nc
# Trying to open:  /data/workflows/BONA_black_spruce_SWC_SA/sample_000000021/output/RH_monthly_tr.nc
# depth: 0.15 m
# depth: 0.4 m
# depth: 0.15 m
# depth: 0.4 m
# Trying to open:  /data/workflows/BONA_black_spruce_SWC_SA/sample_000000000/output/TLAYER_monthly_tr.nc
# Trying to open:  /data/workflows/BONA_black_spruce_SWC_SA/sample_000000000/output/LAYERDEPTH_monthly_tr.nc
# Trying to open:  /data/workflows/BONA_black_spruce_SWC_SA/sample_000000000/output/LAYERDZ_monthly_tr.nc
# Trying to open:  /data/workflows/BONA_black_spruce_SWC_SA/sample_000000000/output/GPP_monthly_tr.nc
# Trying to open:  /data/workflows/BONA_black_spruce_SWC_SA/sample_000000000/output/ALD_yearly_tr.nc
# Trying to open:  /data/workflows/BONA_black_spruce_SWC_SA/sample_000000000/output/RH_monthly_tr.nc
# depth: 0.15 m
# depth: 0.4 m
# depth: 0.15 m
# depth: 0.4 m
# Trying to open:  /data/workflows/BONA_black_spruce_SWC_SA/sample_000000020/output/TLAYER_monthly_tr.nc
# Trying to open:  /data/workflows/BONA_black_spruce_SWC_SA/sample_000000020/output/LAYERDEPTH_monthly_tr.nc
# Trying to open:  /data/workflows/BONA_black_spruce_SWC_SA/sample_000000020/output/LAYERDZ_monthly_tr.nc
# Trying to open:  /data/workflows/BONA_black_spruce_SWC_SA/sample_000000020/output/GPP_monthly_tr.nc
# Trying to open:  /data/workflows/BONA_black_spruce_SWC_SA/sample_000000020/output/ALD_yearly_tr.nc
# Trying to open:  /data/workflows/BONA_black_spruce_SWC_SA/sample_000000020/output/RH_monthly_tr.nc
# depth: 0.15 m
# depth: 0.4 m
# depth: 0.15 m
# depth: 0.4 m
# Trying to open:  /data/workflows/BONA_black_spruce_SWC_SA/sample_000000018/output/TLAYER_monthly_tr.nc
# Trying to open:  /data/workflows/BONA_black_spruce_SWC_SA/sample_000000018/output/LAYERDEPTH_monthly_tr.nc
# Trying to open:  /data/workflows/BONA_black_spruce_SWC_SA/sample_000000018/output/LAYERDZ_monthly_tr.nc
# Trying to open:  /data/workflows/BONA_black_spruce_SWC_SA/sample_000000018/output/GPP_monthly_tr.nc
# Trying to open:  /data/workflows/BONA_black_spruce_SWC_SA/sample_000000018/output/ALD_yearly_tr.nc
# Trying to open:  /data/workflows/BONA_black_spruce_SWC_SA/sample_000000018/output/RH_monthly_tr.nc
# depth: 0.15 m
# depth: 0.4 m
# depth: 0.15 m
# depth: 0.4 m
# Trying to open:  /data/workflows/BONA_black_spruce_SWC_SA/sample_000000002/output/TLAYER_monthly_tr.nc
# Trying to open:  /data/workflows/BONA_black_spruce_SWC_SA/sample_000000002/output/LAYERDEPTH_monthly_tr.nc
# Trying to open:  /data/workflows/BONA_black_spruce_SWC_SA/sample_000000002/output/LAYERDZ_monthly_tr.nc
# Trying to open:  /data/workflows/BONA_black_spruce_SWC_SA/sample_000000002/output/GPP_monthly_tr.nc
# Trying to open:  /data/workflows/BONA_black_spruce_SWC_SA/sample_000000002/output/ALD_yearly_tr.nc
# Trying to open:  /data/workflows/BONA_black_spruce_SWC_SA/sample_000000002/output/RH_monthly_tr.nc
# depth: 0.15 m
# depth: 0.4 m
# depth: 0.15 m
# depth: 0.4 m
# Trying to open:  /data/workflows/BONA_black_spruce_SWC_SA/sample_000000045/output/TLAYER_monthly_tr.nc
# Trying to open:  /data/workflows/BONA_black_spruce_SWC_SA/sample_000000045/output/LAYERDEPTH_monthly_tr.nc
# Trying to open:  /data/workflows/BONA_black_spruce_SWC_SA/sample_000000045/output/LAYERDZ_monthly_tr.nc
# Trying to open:  /data/workflows/BONA_black_spruce_SWC_SA/sample_000000045/output/GPP_monthly_tr.nc
# Trying to open:  /data/workflows/BONA_black_spruce_SWC_SA/sample_000000045/output/ALD_yearly_tr.nc
# Trying to open:  /data/workflows/BONA_black_spruce_SWC_SA/sample_000000045/output/RH_monthly_tr.nc
# depth: 0.15 m
# depth: 0.4 m
# depth: 0.15 m
# depth: 0.4 m
# Trying to open:  /data/workflows/BONA_black_spruce_SWC_SA/sample_000000046/output/TLAYER_monthly_tr.nc
# Trying to open:  /data/workflows/BONA_black_spruce_SWC_SA/sample_000000046/output/LAYERDEPTH_monthly_tr.nc
# Trying to open:  /data/workflows/BONA_black_spruce_SWC_SA/sample_000000046/output/LAYERDZ_monthly_tr.nc
# Trying to open:  /data/workflows/BONA_black_spruce_SWC_SA/sample_000000046/output/GPP_monthly_tr.nc
# Trying to open:  /data/workflows/BONA_black_spruce_SWC_SA/sample_000000046/output/ALD_yearly_tr.nc
# Trying to open:  /data/workflows/BONA_black_spruce_SWC_SA/sample_000000046/output/RH_monthly_tr.nc
# depth: 0.15 m
# depth: 0.4 m
# depth: 0.15 m
# depth: 0.4 m
# Trying to open:  /data/workflows/BONA_black_spruce_SWC_SA/sample_000000006/output/TLAYER_monthly_tr.nc
# Trying to open:  /data/workflows/BONA_black_spruce_SWC_SA/sample_000000006/output/LAYERDEPTH_monthly_tr.nc
# Trying to open:  /data/workflows/BONA_black_spruce_SWC_SA/sample_000000006/output/LAYERDZ_monthly_tr.nc
# Trying to open:  /data/workflows/BONA_black_spruce_SWC_SA/sample_000000006/output/GPP_monthly_tr.nc
# Trying to open:  /data/workflows/BONA_black_spruce_SWC_SA/sample_000000006/output/ALD_yearly_tr.nc
# Trying to open:  /data/workflows/BONA_black_spruce_SWC_SA/sample_000000006/output/RH_monthly_tr.nc
# depth: 0.15 m
# depth: 0.4 m
# depth: 0.15 m
# depth: 0.4 m
# Trying to open:  /data/workflows/BONA_black_spruce_SWC_SA/sample_000000013/output/TLAYER_monthly_tr.nc
# Trying to open:  /data/workflows/BONA_black_spruce_SWC_SA/sample_000000013/output/LAYERDEPTH_monthly_tr.nc
# Trying to open:  /data/workflows/BONA_black_spruce_SWC_SA/sample_000000013/output/LAYERDZ_monthly_tr.nc
# Trying to open:  /data/workflows/BONA_black_spruce_SWC_SA/sample_000000013/output/GPP_monthly_tr.nc
# Trying to open:  /data/workflows/BONA_black_spruce_SWC_SA/sample_000000013/output/ALD_yearly_tr.nc
# Trying to open:  /data/workflows/BONA_black_spruce_SWC_SA/sample_000000013/output/RH_monthly_tr.nc
# depth: 0.15 m
# depth: 0.4 m
# depth: 0.15 m
# depth: 0.4 m
# Trying to open:  /data/workflows/BONA_black_spruce_SWC_SA/sample_000000017/output/TLAYER_monthly_tr.nc
# Trying to open:  /data/workflows/BONA_black_spruce_SWC_SA/sample_000000017/output/LAYERDEPTH_monthly_tr.nc
# Trying to open:  /data/workflows/BONA_black_spruce_SWC_SA/sample_000000017/output/LAYERDZ_monthly_tr.nc
# Trying to open:  /data/workflows/BONA_black_spruce_SWC_SA/sample_000000017/output/GPP_monthly_tr.nc
# Trying to open:  /data/workflows/BONA_black_spruce_SWC_SA/sample_000000017/output/ALD_yearly_tr.nc
# Trying to open:  /data/workflows/BONA_black_spruce_SWC_SA/sample_000000017/output/RH_monthly_tr.nc
# depth: 0.15 m
# depth: 0.4 m
# depth: 0.15 m
# depth: 0.4 m
# Trying to open:  /data/workflows/BONA_black_spruce_SWC_SA/sample_000000009/output/TLAYER_monthly_tr.nc
# Trying to open:  /data/workflows/BONA_black_spruce_SWC_SA/sample_000000009/output/LAYERDEPTH_monthly_tr.nc
# Trying to open:  /data/workflows/BONA_black_spruce_SWC_SA/sample_000000009/output/LAYERDZ_monthly_tr.nc
# Trying to open:  /data/workflows/BONA_black_spruce_SWC_SA/sample_000000009/output/GPP_monthly_tr.nc
# Trying to open:  /data/workflows/BONA_black_spruce_SWC_SA/sample_000000009/output/ALD_yearly_tr.nc
# Trying to open:  /data/workflows/BONA_black_spruce_SWC_SA/sample_000000009/output/RH_monthly_tr.nc
# depth: 0.15 m
# depth: 0.4 m
# depth: 0.15 m
# depth: 0.4 m
# Trying to open:  /data/workflows/BONA_black_spruce_SWC_SA/sample_000000027/output/TLAYER_monthly_tr.nc
# Trying to open:  /data/workflows/BONA_black_spruce_SWC_SA/sample_000000027/output/LAYERDEPTH_monthly_tr.nc
# Trying to open:  /data/workflows/BONA_black_spruce_SWC_SA/sample_000000027/output/LAYERDZ_monthly_tr.nc
# Trying to open:  /data/workflows/BONA_black_spruce_SWC_SA/sample_000000027/output/GPP_monthly_tr.nc
# Trying to open:  /data/workflows/BONA_black_spruce_SWC_SA/sample_000000027/output/ALD_yearly_tr.nc
# Trying to open:  /data/workflows/BONA_black_spruce_SWC_SA/sample_000000027/output/RH_monthly_tr.nc
# depth: 0.15 m
# depth: 0.4 m
# depth: 0.15 m
# depth: 0.4 m
# Trying to open:  /data/workflows/BONA_black_spruce_SWC_SA/sample_000000033/output/TLAYER_monthly_tr.nc
# Trying to open:  /data/workflows/BONA_black_spruce_SWC_SA/sample_000000033/output/LAYERDEPTH_monthly_tr.nc
# Trying to open:  /data/workflows/BONA_black_spruce_SWC_SA/sample_000000033/output/LAYERDZ_monthly_tr.nc
# Trying to open:  /data/workflows/BONA_black_spruce_SWC_SA/sample_000000033/output/GPP_monthly_tr.nc
# Trying to open:  /data/workflows/BONA_black_spruce_SWC_SA/sample_000000033/output/ALD_yearly_tr.nc
# Trying to open:  /data/workflows/BONA_black_spruce_SWC_SA/sample_000000033/output/RH_monthly_tr.nc
# depth: 0.15 m
# depth: 0.4 m
# depth: 0.15 m
# depth: 0.4 m
# Trying to open:  /data/workflows/BONA_black_spruce_SWC_SA/sample_000000044/output/TLAYER_monthly_tr.nc
# Trying to open:  /data/workflows/BONA_black_spruce_SWC_SA/sample_000000044/output/LAYERDEPTH_monthly_tr.nc
# Trying to open:  /data/workflows/BONA_black_spruce_SWC_SA/sample_000000044/output/LAYERDZ_monthly_tr.nc
# Trying to open:  /data/workflows/BONA_black_spruce_SWC_SA/sample_000000044/output/GPP_monthly_tr.nc
# Trying to open:  /data/workflows/BONA_black_spruce_SWC_SA/sample_000000044/output/ALD_yearly_tr.nc
# Trying to open:  /data/workflows/BONA_black_spruce_SWC_SA/sample_000000044/output/RH_monthly_tr.nc
# depth: 0.15 m
# depth: 0.4 m
# depth: 0.15 m
# depth: 0.4 m
# Trying to open:  /data/workflows/BONA_black_spruce_SWC_SA/sample_000000036/output/TLAYER_monthly_tr.nc
# Trying to open:  /data/workflows/BONA_black_spruce_SWC_SA/sample_000000036/output/LAYERDEPTH_monthly_tr.nc
# Trying to open:  /data/workflows/BONA_black_spruce_SWC_SA/sample_000000036/output/LAYERDZ_monthly_tr.nc
# Trying to open:  /data/workflows/BONA_black_spruce_SWC_SA/sample_000000036/output/GPP_monthly_tr.nc
# Trying to open:  /data/workflows/BONA_black_spruce_SWC_SA/sample_000000036/output/ALD_yearly_tr.nc
# Trying to open:  /data/workflows/BONA_black_spruce_SWC_SA/sample_000000036/output/RH_monthly_tr.nc
# depth: 0.15 m
# depth: 0.4 m
# depth: 0.15 m
# depth: 0.4 m
# Trying to open:  /data/workflows/BONA_black_spruce_SWC_SA/sample_000000043/output/TLAYER_monthly_tr.nc
# Trying to open:  /data/workflows/BONA_black_spruce_SWC_SA/sample_000000043/output/LAYERDEPTH_monthly_tr.nc
# Trying to open:  /data/workflows/BONA_black_spruce_SWC_SA/sample_000000043/output/LAYERDZ_monthly_tr.nc
# Trying to open:  /data/workflows/BONA_black_spruce_SWC_SA/sample_000000043/output/GPP_monthly_tr.nc
# Trying to open:  /data/workflows/BONA_black_spruce_SWC_SA/sample_000000043/output/ALD_yearly_tr.nc
# Trying to open:  /data/workflows/BONA_black_spruce_SWC_SA/sample_000000043/output/RH_monthly_tr.nc
# depth: 0.15 m
# depth: 0.4 m
# depth: 0.15 m
# depth: 0.4 m
# Trying to open:  /data/workflows/BONA_black_spruce_SWC_SA/sample_000000012/output/TLAYER_monthly_tr.nc
# Trying to open:  /data/workflows/BONA_black_spruce_SWC_SA/sample_000000012/output/LAYERDEPTH_monthly_tr.nc
# Trying to open:  /data/workflows/BONA_black_spruce_SWC_SA/sample_000000012/output/LAYERDZ_monthly_tr.nc
# Trying to open:  /data/workflows/BONA_black_spruce_SWC_SA/sample_000000012/output/GPP_monthly_tr.nc
# Trying to open:  /data/workflows/BONA_black_spruce_SWC_SA/sample_000000012/output/ALD_yearly_tr.nc
# Trying to open:  /data/workflows/BONA_black_spruce_SWC_SA/sample_000000012/output/RH_monthly_tr.nc
# depth: 0.15 m
# depth: 0.4 m
# depth: 0.15 m
# depth: 0.4 m
# Trying to open:  /data/workflows/BONA_black_spruce_SWC_SA/sample_000000029/output/TLAYER_monthly_tr.nc
# Trying to open:  /data/workflows/BONA_black_spruce_SWC_SA/sample_000000029/output/LAYERDEPTH_monthly_tr.nc
# Trying to open:  /data/workflows/BONA_black_spruce_SWC_SA/sample_000000029/output/LAYERDZ_monthly_tr.nc
# Trying to open:  /data/workflows/BONA_black_spruce_SWC_SA/sample_000000029/output/GPP_monthly_tr.nc
# Trying to open:  /data/workflows/BONA_black_spruce_SWC_SA/sample_000000029/output/ALD_yearly_tr.nc
# Trying to open:  /data/workflows/BONA_black_spruce_SWC_SA/sample_000000029/output/RH_monthly_tr.nc
# depth: 0.15 m
# depth: 0.4 m
# depth: 0.15 m
# depth: 0.4 m
# Trying to open:  /data/workflows/BONA_black_spruce_SWC_SA/sample_000000047/output/TLAYER_monthly_tr.nc
# Trying to open:  /data/workflows/BONA_black_spruce_SWC_SA/sample_000000047/output/LAYERDEPTH_monthly_tr.nc
# Trying to open:  /data/workflows/BONA_black_spruce_SWC_SA/sample_000000047/output/LAYERDZ_monthly_tr.nc
# Trying to open:  /data/workflows/BONA_black_spruce_SWC_SA/sample_000000047/output/GPP_monthly_tr.nc
# Trying to open:  /data/workflows/BONA_black_spruce_SWC_SA/sample_000000047/output/ALD_yearly_tr.nc
# Trying to open:  /data/workflows/BONA_black_spruce_SWC_SA/sample_000000047/output/RH_monthly_tr.nc
# depth: 0.15 m
# depth: 0.4 m
# depth: 0.15 m
# depth: 0.4 m
# Trying to open:  /data/workflows/BONA_black_spruce_SWC_SA/sample_000000024/output/TLAYER_monthly_tr.nc
# Trying to open:  /data/workflows/BONA_black_spruce_SWC_SA/sample_000000024/output/LAYERDEPTH_monthly_tr.nc
# Trying to open:  /data/workflows/BONA_black_spruce_SWC_SA/sample_000000024/output/LAYERDZ_monthly_tr.nc
# Trying to open:  /data/workflows/BONA_black_spruce_SWC_SA/sample_000000024/output/GPP_monthly_tr.nc
# Trying to open:  /data/workflows/BONA_black_spruce_SWC_SA/sample_000000024/output/ALD_yearly_tr.nc
# Trying to open:  /data/workflows/BONA_black_spruce_SWC_SA/sample_000000024/output/RH_monthly_tr.nc
# depth: 0.15 m
# depth: 0.4 m
# depth: 0.15 m
# depth: 0.4 m
# Trying to open:  /data/workflows/BONA_black_spruce_SWC_SA/sample_000000005/output/TLAYER_monthly_tr.nc
# Trying to open:  /data/workflows/BONA_black_spruce_SWC_SA/sample_000000005/output/LAYERDEPTH_monthly_tr.nc
# Trying to open:  /data/workflows/BONA_black_spruce_SWC_SA/sample_000000005/output/LAYERDZ_monthly_tr.nc
# Trying to open:  /data/workflows/BONA_black_spruce_SWC_SA/sample_000000005/output/GPP_monthly_tr.nc
# Trying to open:  /data/workflows/BONA_black_spruce_SWC_SA/sample_000000005/output/ALD_yearly_tr.nc
# Trying to open:  /data/workflows/BONA_black_spruce_SWC_SA/sample_000000005/output/RH_monthly_tr.nc
# depth: 0.15 m
# depth: 0.4 m
# depth: 0.15 m
# depth: 0.4 m
# Trying to open:  /data/workflows/BONA_black_spruce_SWC_SA/sample_000000008/output/TLAYER_monthly_tr.nc
# Trying to open:  /data/workflows/BONA_black_spruce_SWC_SA/sample_000000008/output/LAYERDEPTH_monthly_tr.nc
# Trying to open:  /data/workflows/BONA_black_spruce_SWC_SA/sample_000000008/output/LAYERDZ_monthly_tr.nc
# Trying to open:  /data/workflows/BONA_black_spruce_SWC_SA/sample_000000008/output/GPP_monthly_tr.nc
# Trying to open:  /data/workflows/BONA_black_spruce_SWC_SA/sample_000000008/output/ALD_yearly_tr.nc
# Trying to open:  /data/workflows/BONA_black_spruce_SWC_SA/sample_000000008/output/RH_monthly_tr.nc
# depth: 0.15 m
# depth: 0.4 m
# depth: 0.15 m
# depth: 0.4 m
# Trying to open:  /data/workflows/BONA_black_spruce_SWC_SA/sample_000000025/output/TLAYER_monthly_tr.nc
# Trying to open:  /data/workflows/BONA_black_spruce_SWC_SA/sample_000000025/output/LAYERDEPTH_monthly_tr.nc
# Trying to open:  /data/workflows/BONA_black_spruce_SWC_SA/sample_000000025/output/LAYERDZ_monthly_tr.nc
# Trying to open:  /data/workflows/BONA_black_spruce_SWC_SA/sample_000000025/output/GPP_monthly_tr.nc
# Trying to open:  /data/workflows/BONA_black_spruce_SWC_SA/sample_000000025/output/ALD_yearly_tr.nc
# Trying to open:  /data/workflows/BONA_black_spruce_SWC_SA/sample_000000025/output/RH_monthly_tr.nc
# depth: 0.15 m
# depth: 0.4 m
# depth: 0.15 m
# depth: 0.4 m
# Trying to open:  /data/workflows/BONA_black_spruce_SWC_SA/sample_000000010/output/TLAYER_monthly_tr.nc
# Trying to open:  /data/workflows/BONA_black_spruce_SWC_SA/sample_000000010/output/LAYERDEPTH_monthly_tr.nc
# Trying to open:  /data/workflows/BONA_black_spruce_SWC_SA/sample_000000010/output/LAYERDZ_monthly_tr.nc
# Trying to open:  /data/workflows/BONA_black_spruce_SWC_SA/sample_000000010/output/GPP_monthly_tr.nc
# Trying to open:  /data/workflows/BONA_black_spruce_SWC_SA/sample_000000010/output/ALD_yearly_tr.nc
# Trying to open:  /data/workflows/BONA_black_spruce_SWC_SA/sample_000000010/output/RH_monthly_tr.nc
# depth: 0.15 m
# depth: 0.4 m
# depth: 0.15 m
# depth: 0.4 m
# Trying to open:  /data/workflows/BONA_black_spruce_SWC_SA/sample_000000031/output/TLAYER_monthly_tr.nc
# Trying to open:  /data/workflows/BONA_black_spruce_SWC_SA/sample_000000031/output/LAYERDEPTH_monthly_tr.nc
# Trying to open:  /data/workflows/BONA_black_spruce_SWC_SA/sample_000000031/output/LAYERDZ_monthly_tr.nc
# Trying to open:  /data/workflows/BONA_black_spruce_SWC_SA/sample_000000031/output/GPP_monthly_tr.nc
# Trying to open:  /data/workflows/BONA_black_spruce_SWC_SA/sample_000000031/output/ALD_yearly_tr.nc
# Trying to open:  /data/workflows/BONA_black_spruce_SWC_SA/sample_000000031/output/RH_monthly_tr.nc
# depth: 0.15 m
# depth: 0.4 m
# depth: 0.15 m
# depth: 0.4 m
# Trying to open:  /data/workflows/BONA_black_spruce_SWC_SA/sample_000000030/output/TLAYER_monthly_tr.nc
# Trying to open:  /data/workflows/BONA_black_spruce_SWC_SA/sample_000000030/output/LAYERDEPTH_monthly_tr.nc
# Trying to open:  /data/workflows/BONA_black_spruce_SWC_SA/sample_000000030/output/LAYERDZ_monthly_tr.nc
# Trying to open:  /data/workflows/BONA_black_spruce_SWC_SA/sample_000000030/output/GPP_monthly_tr.nc
# Trying to open:  /data/workflows/BONA_black_spruce_SWC_SA/sample_000000030/output/ALD_yearly_tr.nc
# Trying to open:  /data/workflows/BONA_black_spruce_SWC_SA/sample_000000030/output/RH_monthly_tr.nc
# depth: 0.15 m
# depth: 0.4 m
# depth: 0.15 m
# depth: 0.4 m
# Trying to open:  /data/workflows/BONA_black_spruce_SWC_SA/sample_000000028/output/TLAYER_monthly_tr.nc
# Trying to open:  /data/workflows/BONA_black_spruce_SWC_SA/sample_000000028/output/LAYERDEPTH_monthly_tr.nc
# Trying to open:  /data/workflows/BONA_black_spruce_SWC_SA/sample_000000028/output/LAYERDZ_monthly_tr.nc
# Trying to open:  /data/workflows/BONA_black_spruce_SWC_SA/sample_000000028/output/GPP_monthly_tr.nc
# Trying to open:  /data/workflows/BONA_black_spruce_SWC_SA/sample_000000028/output/ALD_yearly_tr.nc
# Trying to open:  /data/workflows/BONA_black_spruce_SWC_SA/sample_000000028/output/RH_monthly_tr.nc
# depth: 0.15 m
# depth: 0.4 m
# depth: 0.15 m
# depth: 0.4 m
# Trying to open:  /data/workflows/BONA_black_spruce_SWC_SA/sample_000000016/output/TLAYER_monthly_tr.nc
# Trying to open:  /data/workflows/BONA_black_spruce_SWC_SA/sample_000000016/output/LAYERDEPTH_monthly_tr.nc
# Trying to open:  /data/workflows/BONA_black_spruce_SWC_SA/sample_000000016/output/LAYERDZ_monthly_tr.nc
# Trying to open:  /data/workflows/BONA_black_spruce_SWC_SA/sample_000000016/output/GPP_monthly_tr.nc
# Trying to open:  /data/workflows/BONA_black_spruce_SWC_SA/sample_000000016/output/ALD_yearly_tr.nc
# Trying to open:  /data/workflows/BONA_black_spruce_SWC_SA/sample_000000016/output/RH_monthly_tr.nc
# depth: 0.15 m
# depth: 0.4 m
# depth: 0.15 m
# depth: 0.4 m
# Trying to open:  /data/workflows/BONA_black_spruce_SWC_SA/sample_000000007/output/TLAYER_monthly_tr.nc
# Trying to open:  /data/workflows/BONA_black_spruce_SWC_SA/sample_000000007/output/LAYERDEPTH_monthly_tr.nc
# Trying to open:  /data/workflows/BONA_black_spruce_SWC_SA/sample_000000007/output/LAYERDZ_monthly_tr.nc
# Trying to open:  /data/workflows/BONA_black_spruce_SWC_SA/sample_000000007/output/GPP_monthly_tr.nc
# Trying to open:  /data/workflows/BONA_black_spruce_SWC_SA/sample_000000007/output/ALD_yearly_tr.nc
# Trying to open:  /data/workflows/BONA_black_spruce_SWC_SA/sample_000000007/output/RH_monthly_tr.nc
# depth: 0.15 m
# depth: 0.4 m
# depth: 0.15 m
# depth: 0.4 m
# Trying to open:  /data/workflows/BONA_black_spruce_SWC_SA/sample_000000014/output/TLAYER_monthly_tr.nc
# Trying to open:  /data/workflows/BONA_black_spruce_SWC_SA/sample_000000014/output/LAYERDEPTH_monthly_tr.nc
# Trying to open:  /data/workflows/BONA_black_spruce_SWC_SA/sample_000000014/output/LAYERDZ_monthly_tr.nc
# Trying to open:  /data/workflows/BONA_black_spruce_SWC_SA/sample_000000014/output/GPP_monthly_tr.nc
# Trying to open:  /data/workflows/BONA_black_spruce_SWC_SA/sample_000000014/output/ALD_yearly_tr.nc
# Trying to open:  /data/workflows/BONA_black_spruce_SWC_SA/sample_000000014/output/RH_monthly_tr.nc
# depth: 0.15 m
# depth: 0.4 m
# depth: 0.15 m
# depth: 0.4 m
# Trying to open:  /data/workflows/BONA_black_spruce_SWC_SA/sample_000000037/output/TLAYER_monthly_tr.nc
# Trying to open:  /data/workflows/BONA_black_spruce_SWC_SA/sample_000000037/output/LAYERDEPTH_monthly_tr.nc
# Trying to open:  /data/workflows/BONA_black_spruce_SWC_SA/sample_000000037/output/LAYERDZ_monthly_tr.nc
# Trying to open:  /data/workflows/BONA_black_spruce_SWC_SA/sample_000000037/output/GPP_monthly_tr.nc
# Trying to open:  /data/workflows/BONA_black_spruce_SWC_SA/sample_000000037/output/ALD_yearly_tr.nc
# Trying to open:  /data/workflows/BONA_black_spruce_SWC_SA/sample_000000037/output/RH_monthly_tr.nc
# depth: 0.15 m
# depth: 0.4 m
# depth: 0.15 m
# depth: 0.4 m
# Trying to open:  /data/workflows/BONA_black_spruce_SWC_SA/sample_000000023/output/TLAYER_monthly_tr.nc
# Trying to open:  /data/workflows/BONA_black_spruce_SWC_SA/sample_000000023/output/LAYERDEPTH_monthly_tr.nc
# Trying to open:  /data/workflows/BONA_black_spruce_SWC_SA/sample_000000023/output/LAYERDZ_monthly_tr.nc
# Trying to open:  /data/workflows/BONA_black_spruce_SWC_SA/sample_000000023/output/GPP_monthly_tr.nc
# Trying to open:  /data/workflows/BONA_black_spruce_SWC_SA/sample_000000023/output/ALD_yearly_tr.nc
# Trying to open:  /data/workflows/BONA_black_spruce_SWC_SA/sample_000000023/output/RH_monthly_tr.nc
# depth: 0.15 m
# depth: 0.4 m
# depth: 0.15 m
# depth: 0.4 m

# %%
sample_dfs['year'] = sample_dfs['date'].dt.year
sample_dfs['month'] = sample_dfs['date'].dt.month
sample_dfs = sample_dfs.loc[sample_dfs['year']>=2017]
sample_dfs.columns = ['date', 'sample', 'GPP', 'RH', 'ALD', 'year', 'month']

lwc_layers['year'] = lwc_layers['time'].dt.year
lwc_layers['month'] = lwc_layers['time'].dt.month
lwc_layers = lwc_layers.loc[lwc_layers['year']>=2017]

t_layers['year'] = t_layers['time'].dt.year
t_layers['month'] = t_layers['time'].dt.month
t_layers = t_layers.loc[t_layers['year']>=2017]

# %%
lwc_layers
# Out:
#            time  x  y  layer     z  type  LWCLAYER  LWCLAYER_top  \
# 1416 2017-01-30  0  0      0  0.15   2.0  0.000000      0.000000
# 1417 2017-03-02  0  0      0  0.15   2.0  0.000000      0.000000
# 1418 2017-03-02  0  0      0  0.15   2.0  0.000000      0.000000
# 1419 2017-03-02  0  0      0  0.15   2.0  0.000000      0.000000
# 1420 2017-03-02  0  0      0  0.15   2.0  0.000000      0.000000
# ...         ... .. ..    ...   ...   ...       ...           ...
# 1591 2022-12-01  0  0      1  0.40   3.0  0.157758      0.257194
# 1592 2022-12-31  0  0      1  0.40   3.0  0.000000      0.000000
# 1593 2022-12-31  0  0      1  0.40   3.0  0.000000      0.000000
# 1594 2022-12-31  0  0      1  0.40   3.0  0.000000      0.000000
# 1595 2022-12-31  0  0      1  0.40   3.0  0.000000      0.000000
#
#       LWCLAYER_bot  sample  year  month
# 1416           0.0      38  2017      1
# 1417           0.0      38  2017      3
# 1418           0.0      38  2017      3
# 1419           0.0      38  2017      3
# 1420           0.0      38  2017      3
# ...            ...     ...   ...    ...
# 1591           0.0      23  2022     12
# 1592           0.0      23  2022     12
# 1593           0.0      23  2022     12
# 1594           0.0      23  2022     12
# 1595           0.0      23  2022     12
#
# [18000 rows x 12 columns]

# %%
path_to_tripod_data = '/data/comparison_data/BONA_Tripod_SM_TSoil.xlsx'

# %%
tripod_data = pd.read_excel(path_to_tripod_data, sheet_name='Long', parse_dates = ['Date'])
tripod_data = tripod_data.replace('NAN', np.nan)

# %%
tripod_data['month'] = tripod_data['Date'].dt.month
tripod_data['year'] = tripod_data['Date'].dt.year
tripod_data_monthly = tripod_data.groupby(by=['Location', 'year', 'month']).mean().reset_index()
tripod_data_monthly['day'] = 1
tripod_data_monthly['m_y'] = pd.to_datetime(tripod_data_monthly[['year', 'month', 'day']])

# %%
fig, axes = plt.subplots(2, 1, sharex=True)

#sns.lineplot(data=lwc_layers[lwc_layers['z']==.15], x='time', y='LWCLAYER', hue='sample', legend=False, ax=axes[0], alpha=0.3)
sns.lineplot(data=lwc_layers[(lwc_layers['z']==.15) & (lwc_layers['sample']==0)], x='time', y='LWCLAYER', color='red', ax=axes[0])

#sns.scatterplot(tripod_data_monthly[tripod_data_monthly['Location']=='WTT3'], label='WTT3', 
#             x='m_y', y = 'soil_moisture_15cm(%)', ax=axes[0])
#sns.scatterplot(tripod_data_monthly[tripod_data_monthly['Location']=='WTT2'], label='WTT2', 
#             x='m_y', y = 'soil_moisture_15cm(%)', ax=axes[0])
sns.scatterplot(tripod_data_monthly[tripod_data_monthly['Location']=='WTT1'], label='WTT2', 
             x='m_y', y = 'soil_moisture_15cm(%)', ax=axes[0])


#sns.lineplot(data=lwc_layers[lwc_layers['z']==.4], x='time', y='LWCLAYER', hue='sample', legend=False, ax=axes[1], alpha=0.3)
sns.lineplot(data=lwc_layers[(lwc_layers['z']==.4) & (lwc_layers['sample']==0)], x='time', y='LWCLAYER', color='red', ax=axes[1])


#sns.scatterplot(tripod_data_monthly[tripod_data_monthly['Location']=='WTT3'], 
#             x='m_y', y = 'soil_moisture_40cm(%)', ax=axes[1])
#sns.scatterplot(tripod_data_monthly[tripod_data_monthly['Location']=='WTT2'], 
#             x='m_y', y = 'soil_moisture_40cm(%)', ax=axes[1])
sns.scatterplot(tripod_data_monthly[tripod_data_monthly['Location']=='WTT1'], 
             x='m_y', y = 'soil_moisture_40cm(%)', ax=axes[1])

plt.xticks(rotation=70)

plt.xlabel('')
axes[0].set_ylabel('soil moisture 15 cm (C)')
axes[1].set_ylabel('soil moisture 40 cm (C)')

plt.xticks(rotation=70)


fig.tight_layout()

plt.savefig('BONA_SWC_SA_LWC_soil.jpg', dpi=300)

# %%
fig, axes = plt.subplots(2, 1, sharex=True)

sns.lineplot(data=t_layers[t_layers['z']==.15], x='time', y='TLAYER', hue='sample', legend=False, alpha = 0.3, ax=axes[0])
#sns.lineplot(data=t_layers[(t_layers['z']==.15) & (t_layers['sample']==5)], x='time', y='TLAYER', color='red', ax=axes[0])

#sns.scatterplot(tripod_data_monthly[tripod_data_monthly['Location']=='WTT3'], label='WTT3', 
#             x='m_y', y = 'soil_temp_15cm(°C)', ax=axes[0])
#sns.scatterplot(tripod_data_monthly[tripod_data_monthly['Location']=='WTT2'], label='WTT2',
#             x='m_y', y = 'soil_temp_15cm(°C)', ax=axes[0])
sns.scatterplot(tripod_data_monthly[tripod_data_monthly['Location']=='WTT1'], label='WTT1',
             x='m_y', y = 'soil_temp_15cm(°C)', ax=axes[0])


#sns.lineplot(data=t_layers[t_layers['z']==.4], x='time', y='TLAYER', hue='sample', alpha=0.3, ax=axes[1], legend=False)
#sns.lineplot(data=t_layers[(t_layers['z']==.4) & (t_layers['sample']==5)], x='time', y='TLAYER', color='red', ax=axes[1])
#sns.lineplot(data=t_layers[(t_layers['z']==.4) & (t_layers['sample']==20)], x='time', y='TLAYER_top', color='red', ax=axes[1])
#sns.lineplot(data=t_layers[(t_layers['z']==.4) & (t_layers['sample']==20)], x='time', y='TLAYER_bot', color='red', ax=axes[1])

#sns.scatterplot(tripod_data_monthly[tripod_data_monthly['Location']=='WTT3'], 
#             x='m_y', y = 'soil_temp_40cm(°C)', ax=axes[1])
#sns.scatterplot(tripod_data_monthly[tripod_data_monthly['Location']=='WTT2'], 
#             x='m_y', y = 'soil_temp_40cm(°C)', ax=axes[1])
sns.scatterplot(tripod_data_monthly[tripod_data_monthly['Location']=='WTT1'], 
             x='m_y', y = 'soil_temp_40cm(°C)', ax=axes[1])


plt.xlabel('')
axes[0].set_ylabel('soil temp 15 cm (C)')
axes[1].set_ylabel('soil temp 40 cm (C)')

plt.xticks(rotation=70)


fig.tight_layout()

plt.savefig('BONA_SWC_SA_T_soil.jpg', dpi=300)

# %%
sns.scatterplot(data=sample_dfs.loc[sample_dfs['sample']==0], x='year', y='ALD', hue='sample')
# Out:
# <AxesSubplot:xlabel='year', ylabel='ALD'>

# %%
sample_dfs
# Out:
#                  date  sample         GPP         RH       ALD  year  month
# 2017-01-01 2017-01-01      38    0.000000   0.334874  0.422009  2017      1
# 2017-02-01 2017-02-01      38    0.000000   0.349829       NaN  2017      2
# 2017-03-01 2017-03-01      38    0.000000   0.357381       NaN  2017      3
# 2017-04-01 2017-04-01      38    0.000000   0.440058       NaN  2017      4
# 2017-05-01 2017-05-01      38   81.627791  57.697624       NaN  2017      5
# ...               ...     ...         ...        ...       ...   ...    ...
# 2022-08-01 2022-08-01      23  119.115843   0.005866       NaN  2022      8
# 2022-09-01 2022-09-01      23   67.662243  65.281456       NaN  2022      9
# 2022-10-01 2022-10-01      23    0.000000   5.553937       NaN  2022     10
# 2022-11-01 2022-11-01      23    0.000000   0.752808       NaN  2022     11
# 2022-12-01 2022-12-01      23    0.000000   0.533379       NaN  2022     12
#
# [3600 rows x 7 columns]

# %%
sample_matrix=pd.read_csv(os.path.join(SA_path, 'sample_matrix.csv'))
sample_matrix.iloc[42]
# Out:
# hksat(m)       0.144009
# hksat(f)       0.279589
# hksat(h)       0.002274
# tcsolid(m)     0.249434
# tcsolid(f)     0.236660
# tcsolid(h)     0.262749
# porosity(m)    0.972268
# porosity(f)    0.936730
# porosity(h)    0.815291
# nfactor(s)     1.719638
# nfactor(w)     0.818087
# rhq10          1.810547
# Name: 42, dtype: float64

# %%
sample_matrix.iloc[35]
# Out:
# hksat(m)       0.148619
# hksat(f)       0.281563
# hksat(h)       0.002621
# tcsolid(m)     0.266066
# tcsolid(f)     0.245980
# tcsolid(h)     0.236680
# porosity(m)    0.968831
# porosity(f)    0.955508
# porosity(h)    0.774564
# nfactor(s)     1.270240
# nfactor(w)     0.857197
# rhq10          2.104604
# Name: 35, dtype: float64

# %%
sample_summary_s = sample_dfs.loc[(sample_dfs['month']>7) & (sample_dfs['month']<9), ['sample', 'GPP', 'RH', 'ALD']].groupby(by='sample').mean()
t_layers_summary_s = t_layers.loc[(t_layers['month']>7) & (t_layers['month']<9), ['sample', 'z', 'type', 'TLAYER']].groupby(by=['sample', 'z']).mean().reset_index()
lwc_layers_summary_s = lwc_layers.loc[(lwc_layers['month']>7) & (lwc_layers['month']<9), ['sample', 'z', 'type', 'LWCLAYER']].groupby(by=['sample', 'z']).mean().reset_index()

sample_summary_s = sample_summary_s.merge(sample_matrix, left_index=True, right_index=True)
sample_summary_s = sample_summary_s.merge(t_layers_summary_s, left_index=True, right_on='sample', how='right')
sample_summary_s = sample_summary_s.merge(lwc_layers_summary_s, on=['sample', 'z'])

sample_summary_w = sample_dfs.loc[(sample_dfs['month']<6) | (sample_dfs['month']>=10), ['sample', 'GPP', 'RH', 'ALD']].groupby(by='sample').mean()
t_layers_summary_w = t_layers.loc[(t_layers['month']<6) | (t_layers['month']>=10), ['sample', 'z', 'type', 'TLAYER']].groupby(by=['sample', 'z']).mean().reset_index()
lwc_layers_summary_w = lwc_layers.loc[(lwc_layers['month']<6) | (lwc_layers['month']>=10), ['sample', 'z', 'type', 'LWCLAYER']].groupby(by=['sample', 'z']).mean().reset_index()

sample_summary_w = sample_summary_w.merge(sample_matrix, left_index=True, right_index=True)
sample_summary_w = sample_summary_w.merge(t_layers_summary_w, left_index=True, right_on='sample', how='right')
sample_summary_w = sample_summary_w.merge(lwc_layers_summary_w, on=['sample', 'z'])

# %%
sns.pairplot(data=sample_summary_s, x_vars=['hksat(m)','hksat(f)','hksat(h)',
          'tcsolid(m)', 'tcsolid(f)', 'tcsolid(h)'], y_vars= ['GPP', 'RH', 'TLAYER', 'LWCLAYER'], hue='z', kind='reg')

# %%
sns.pairplot(data=sample_summary_s, x_vars=['porosity(m)', 'porosity(f)', 'porosity(h)', 'nfactor(s)', 'nfactor(w)', 'rhq10'], 
             y_vars= ['GPP', 'RH', 'TLAYER', 'LWCLAYER'], hue='z', kind='reg')

# %%
sns.pairplot(data=sample_summary_w, x_vars=['hksat(m)','hksat(f)','hksat(h)',
          'tcsolid(m)', 'tcsolid(f)', 'tcsolid(h)'], y_vars= ['ALD', 'GPP', 'RH', 'TLAYER', 'LWCLAYER'], hue='z', kind='reg')

# %%
sns.pairplot(data=sample_summary_w, x_vars=['porosity(m)', 'porosity(f)', 'porosity(h)', 'nfactor(s)', 'nfactor(w)', 'rhq10'], 
             y_vars= ['ALD', 'GPP', 'RH', 'TLAYER', 'LWCLAYER'], hue='z', kind='reg')

# %%
sample_summary_s
# Out:
#            GPP         RH  ALD  hksat(m)  hksat(f)  hksat(h)  tcsolid(m)  \
# 0   123.100652  43.867674  NaN  0.143194  0.263254  0.001795    0.234352
# 1   123.100652  43.867674  NaN  0.143194  0.263254  0.001795    0.234352
# 2   121.736431   8.798500  NaN  0.145306  0.280772  0.001059    0.267408
# 3   121.736431   8.798500  NaN  0.145306  0.280772  0.001059    0.267408
# 4   124.075871  33.858151  NaN  0.143349  0.282777  0.001447    0.254354
# ..         ...        ...  ...       ...       ...       ...         ...
# 95  122.745471  26.001506  NaN  0.153289  0.282551  0.001817    0.251815
# 96  122.016160  17.353067  NaN  0.155558  0.265807  0.002707    0.257182
# 97  122.016160  17.353067  NaN  0.155558  0.265807  0.002707    0.257182
# 98  121.671136  13.595407  NaN  0.149635  0.278532  0.001985    0.266666
# 99  121.671136  13.595407  NaN  0.149635  0.278532  0.001985    0.266666
#
#     tcsolid(f)  tcsolid(h)  porosity(m)  ...  porosity(h)  nfactor(s)  \
# 0     0.257619    0.232487     0.961162  ...     0.792078    1.624844
# 1     0.257619    0.232487     0.961162  ...     0.792078    1.624844
# 2     0.235695    0.259389     0.968639  ...     0.792830    1.283696
# 3     0.235695    0.259389     0.968639  ...     0.792830    1.283696
# 4     0.252266    0.237873     0.972151  ...     0.754554    1.769331
# ..         ...         ...          ...  ...          ...         ...
# 95    0.269865    0.265549     0.970280  ...     0.777758    1.573252
# 96    0.249286    0.230480     0.969852  ...     0.794338    1.344087
# 97    0.249286    0.230480     0.969852  ...     0.794338    1.344087
# 98    0.253039    0.233175     0.977936  ...     0.796729    1.303392
# 99    0.253039    0.233175     0.977936  ...     0.796729    1.303392
#
#     nfactor(w)     rhq10  sample     z  type_x    TLAYER  type_y  LWCLAYER
# 0     0.808234  2.187964       0  0.15     2.0  2.861585     2.0  0.459961
# 1     0.808234  2.187964       0  0.40     3.0  0.117657     3.0  0.302705
# 2     0.916858  1.946545       1  0.15     2.0  2.177757     2.0  0.481534
# 3     0.916858  1.946545       1  0.40     3.0 -0.019698     3.0  0.117839
# 4     1.186253  2.123359       2  0.15     2.0  3.381133     2.0  0.429157
# ..         ...       ...     ...   ...     ...       ...     ...       ...
# 95    1.144945  2.179808      47  0.40     3.0  0.085609     3.0  0.274736
# 96    0.830345  1.851552      48  0.15     2.0  2.469183     2.0  0.465174
# 97    0.830345  1.851552      48  0.40     3.0 -0.009581     3.0  0.151435
# 98    0.876916  1.816347      49  0.15     2.0  2.179637     2.0  0.481543
# 99    0.876916  1.816347      49  0.40     3.0 -0.021000     3.0  0.111146
#
# [100 rows x 21 columns]

# %%
tripod_data_monthly
# Out:
#    Location  year  month  soil_moisture_15cm(%)  soil_moisture_40cm(%)  \
# 0       D13  2021      9                    NaN                    NaN
# 1       D13  2021     10                    NaN                    NaN
# 2       D13  2021     11                    NaN                    NaN
# 3       D13  2021     12                    NaN                    NaN
# 4       D13  2022      1                    NaN                    NaN
# ..      ...   ...    ...                    ...                    ...
# 58     WTT3  2022      4               0.210298               0.184463
# 59     WTT3  2022      5               0.376718               0.267047
# 60     WTT3  2022      6               0.338398               0.309971
# 61     WTT3  2022      7               0.263860               0.282005
# 62     WTT3  2022      8               0.266917               0.269167
#
#     soil_temp_15cm(°C)  soil_temp_40cm(°C)  PAR(µmol/m²/s)  air_temp_1m(°C)  \
# 0                  NaN                 NaN             NaN        -2.504243
# 1                  NaN                 NaN             NaN        -3.134267
# 2                  NaN                 NaN             NaN       -18.891440
# 3                  NaN                 NaN             NaN       -18.087169
# 4                  NaN                 NaN             NaN       -20.166466
# ..                 ...                 ...             ...              ...
# 58           -0.961724           -0.650803      213.892708              NaN
# 59            0.220679           -0.004485      193.718481              NaN
# 60                 NaN                 NaN       98.845833              NaN
# 61           10.547886            9.108664       62.668414              NaN
# 62           10.922423            9.739179       43.976413              NaN
#
#     day        m_y
# 0     1 2021-09-01
# 1     1 2021-10-01
# 2     1 2021-11-01
# 3     1 2021-12-01
# 4     1 2022-01-01
# ..  ...        ...
# 58    1 2022-04-01
# 59    1 2022-05-01
# 60    1 2022-06-01
# 61    1 2022-07-01
# 62    1 2022-08-01
#
# [63 rows x 11 columns]

# %%
tlayer_merged = t_layers[['time', 'z', 'TLAYER', 'sample']].merge(tripod_data_monthly[['m_y', 'soil_temp_15cm(°C)', 'soil_temp_40cm(°C)']], left_on = ['time'], right_on=['m_y'], how='left')
tlayer_merged= tlayer_merged.loc[~tlayer_merged['soil_temp_15cm(°C)'].isna() & ~tlayer_merged['soil_temp_40cm(°C)'].isna() & ~tlayer_merged['TLAYER'].isna()]

lwclayer_merged = lwc_layers[['time', 'z', 'LWCLAYER', 'sample']].merge(tripod_data_monthly[['m_y', 'soil_moisture_15cm(%)', 'soil_moisture_40cm(%)']], left_on = ['time'], right_on=['m_y'], how='left')
lwclayer_merged= lwclayer_merged.loc[~lwclayer_merged['soil_moisture_15cm(%)'].isna() & ~lwclayer_merged['soil_moisture_40cm(%)'].isna() & ~lwclayer_merged['LWCLAYER'].isna()]

# %%
r2s_15cm = []
r2s_40cm = []

samples = []

for sample in tlayer_merged['sample'].unique():
    
    tlayer_sample = tlayer_merged.loc[tlayer_merged['sample']==sample]
    if len(tlayer_sample.loc[tlayer_sample['z']==0.15])>0:
        r2_15cm = r2_score(tlayer_sample.loc[tlayer_sample['z']==0.15, 'soil_temp_15cm(°C)'], tlayer_sample.loc[tlayer_sample['z']==0.15, 'TLAYER'])
        r2_40cm = r2_score(tlayer_sample.loc[tlayer_sample['z']==0.4, 'soil_temp_40cm(°C)'], tlayer_sample.loc[tlayer_sample['z']==0.4, 'TLAYER'])

        samples.append(sample)
        r2s_15cm.append(r2_15cm)
        r2s_40cm.append(r2_40cm)
    
df_tlayer = pd.DataFrame({'sample': samples, 'r2_15cm': r2s_15cm, 'r2_40cm': r2s_40cm})

# %%
lwclayer_r2s_15cm = []
lwclayer_r2s_40cm = []

samples = []
for sample in tlayer_merged['sample'].unique():
    lwclayer_sample = lwclayer_merged.loc[lwclayer_merged['sample']==sample]
    if len(lwclayer_sample.loc[lwclayer_sample['z']==0.15])>0:
        r2_15cm = r2_score(lwclayer_sample.loc[lwclayer_sample['z']==0.15, 'soil_moisture_15cm(%)'], lwclayer_sample.loc[lwclayer_sample['z']==0.15, 'LWCLAYER'])
        r2_40cm = r2_score(lwclayer_sample.loc[lwclayer_sample['z']==0.4, 'soil_moisture_40cm(%)'], lwclayer_sample.loc[lwclayer_sample['z']==0.4, 'LWCLAYER'])

        samples.append(sample)
        lwclayer_r2s_15cm.append(r2_15cm)
        lwclayer_r2s_40cm.append(r2_40cm)
    
df_lwclayer = pd.DataFrame({'sample': samples, 'r2_15cm': lwclayer_r2s_15cm, 'r2_40cm': lwclayer_r2s_40cm})

# %%
df_tlayer.sort_values('r2_15cm', ascending=False).head(20)
# Out:
#     sample   r2_15cm   r2_40cm
# 12      42 -0.294951 -1.028604
# 18      21 -0.298914 -1.061080
# 48      37 -0.341305 -1.067579
# 19       0 -0.388215 -1.047778
# 32      36 -0.459959 -1.232478
# 20      20 -0.525327 -1.260849
# 26      13 -0.530065 -1.256576
# 30      33 -0.564219 -1.311329
# 5       48 -0.565123 -1.215762
# 4        4 -0.593630 -1.218215
# 10      32 -0.600640 -1.284561
# 1       40 -0.601147 -1.360697
# 2       15 -0.611634 -1.237181
# 29      27 -0.625443 -1.213363
# 25       6 -0.636122 -1.328692
# 3        3 -0.646236 -1.316481
# 24      46 -0.674314 -1.326688
# 13      35 -0.687567 -1.332406
# 0       38 -0.709668 -1.378686
# 15      22 -0.713560 -1.469536

# %%
df_lwclayer.sort_values('r2_15cm', ascending=False).head(20)
# Out:
#     sample   r2_15cm    r2_40cm
# 4        4 -3.223136  -9.122667
# 29      27 -3.223458  -9.480080
# 13      35 -3.294353  -9.652230
# 27      17 -3.364542  -9.207120
# 21      18 -3.400732  -9.018259
# 43      30 -3.401738 -10.188096
# 7       19 -3.413432 -10.218190
# 14       1 -3.426914  -9.298268
# 17      49 -3.435460  -9.399779
# 5       48 -3.438588  -8.899001
# 24      46 -3.439491  -9.183932
# 2       15 -3.445498  -8.952459
# 37      24 -3.461673  -9.112802
# 49      23 -3.506666 -10.011243
# 28       9 -3.518563  -9.628030
# 31      44 -3.524709  -9.247138
# 45      16 -3.540032 -10.084885
# 41      10 -3.543102  -8.710096
# 9       39 -3.552804  -8.798302
# 40      25 -3.557705  -8.935754
